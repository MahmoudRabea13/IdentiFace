# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import cv2
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, plot_confusion_matrix
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input, decode_predictions

# %%
train_data_dir = 'images/Augmentation/train'  # Path to training data
test_data_dir = 'images/Augmentation/test/'  # Path to testing data

# Image dimensions (VGGNet input size)
img_width, img_height = 128, 128

# Function to load images and labels
def load_data(data_dir):
    images = []
    labels = []
    label_encoder = LabelEncoder()

    emotions = os.listdir(data_dir)
    label_encoder.fit(emotions)  # Fit LabelEncoder directly on emotions

    for emotion in emotions:
        label_name = emotion  # Extracting label name from folder name
        label = label_encoder.transform([label_name])[0]  # Transform label to encoded integer
        for img_file in os.listdir(os.path.join(data_dir, emotion)):
            img_path = os.path.join(data_dir, emotion, img_file)
            img = cv2.imread(img_path)
            img = img.astype('float32') / 255.0  # Normalize pixel values
            images.append(img)
            labels.append(label)

    return np.array(images), np.array(labels)


# Load training and testing data
X_train, y_train = load_data(train_data_dir)
X_test, y_test = load_data(test_data_dir)

# %%
# Use one-hot encoding for the labels
num_classes = len(np.unique(y_train))
y_train = np.eye(num_classes)[y_train]
y_test = np.eye(num_classes)[y_test]
# Convert one-hot encoded labels back to single labels
y_train_single = np.argmax(y_train, axis=1)
y_test_single = np.argmax(y_test, axis=1)

# Split the training data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %%
import os
import cv2
import numpy as np
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder
from keras.models import Sequential
from keras.layers import Flatten, Dense

# Define the number of splits (K)
n_splits = 5  # You can change this value as needed

# Assuming you have defined X_train, y_train, X_test, and y_test

# Convert one-hot encoded labels back to single labels
y_train_single = np.argmax(y_train, axis=1)

# Initialize K-fold cross-validation
kfold = StratifiedKFold(n_splits=n_splits, shuffle=True)

# Initialize lists to store the results
acc_per_fold = []
loss_per_fold = []

# Start K-fold cross-validation
fold_no = 1
for train_index, test_index in kfold.split(X_train, y_train_single):
    print(f'Fold {fold_no}...')

    # Split data into training and validation sets for this fold
    X_train_fold, X_val_fold = X_train[train_index], X_train[test_index]
    y_train_fold, y_val_fold = y_train[train_index], y_train[test_index]
    
    # Convert one-hot encoded labels back to single labels for this fold
    y_train_fold_single = np.argmax(y_train_fold, axis=1)
    y_val_fold_single = np.argmax(y_val_fold, axis=1)

    # Create a Sequential model
    model = Sequential()

    # Flatten the input
    model.add(Flatten(input_shape=(128, 128, 3)))

    # Add a Dense hidden layer with ReLU activation
    model.add(Dense(128, activation='relu'))

    # Add the output layer with softmax activation for classification (7 classes)
    model.add(Dense(7, activation='softmax'))

    # Compile the model
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    # Train the model for this fold
    history = model.fit(X_train_fold, y_train_fold, epochs=10, batch_size=32, validation_data=(X_val_fold, y_val_fold), verbose=1)

    # Evaluate the model on the validation data
    scores = model.evaluate(X_val_fold, y_val_fold, verbose=0)
    print(f'Score for Fold {fold_no}: {model.metrics_names[0]} of {scores[0]}; {model.metrics_names[1]} of {scores[1] * 100}%')
    acc_per_fold.append(scores[1] * 100)
    loss_per_fold.append(scores[0])

    # Predict probabilities for each class on the validation data
    probabilities = model.predict(X_val_fold)
    for i, probs in enumerate(probabilities):
        print(f"Sample {i + 1} - Probabilities for each class:")
        for class_idx, class_prob in enumerate(probs):
            print(f"Class {class_idx}: Probability - {class_prob:.4f}")

    fold_no += 1

# Print the average results across all folds
print('Average scores across all folds:')
print(f'Accuracy: {np.mean(acc_per_fold)} (+- {np.std(acc_per_fold)})')
print(f'Loss: {np.mean(loss_per_fold)} (+- {np.std(loss_per_fold)})')

# Once K-fold cross-validation is done, you can retrain the model on the entire training data and evaluate on the test data
# Assuming the best model configuration is determined from cross-validation, retrain the model on the full training data
best_model = Sequential()
best_model.add(Flatten(input_shape=(128, 128, 3)))
best_model.add(Dense(128, activation='relu'))
best_model.add(Dense(7, activation='softmax'))
best_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
best_model.fit(X_train, y_train, epochs=10, batch_size=32, verbose=1)

# Evaluate the best model on the test data
test_loss, test_accuracy = best_model.evaluate(X_test, y_test, verbose=0)
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
# Out:
# Fold 1...
# Epoch 1/10
# 59/59 [==============================] - 9s 118ms/step - loss: 8.4757 - accuracy: 0.3129 - val_loss: 1.2852 - val_accuracy: 0.5579
# Epoch 2/10
# 59/59 [==============================] - 7s 114ms/step - loss: 1.0111 - accuracy: 0.6398 - val_loss: 0.6206 - val_accuracy: 0.8841
# Epoch 3/10
# 59/59 [==============================] - 7s 113ms/step - loss: 0.5871 - accuracy: 0.8658 - val_loss: 0.7163 - val_accuracy: 0.7296
# Epoch 4/10
# 59/59 [==============================] - 7s 111ms/step - loss: 0.4532 - accuracy: 0.8846 - val_loss: 0.3405 - val_accuracy: 0.9464
# Epoch 5/10
# 59/59 [==============================] - 6s 105ms/step - loss: 0.3294 - accuracy: 0.9206 - val_loss: 0.2210 - val_accuracy: 0.9936
# Epoch 6/10
# 59/59 [==============================] - 7s 114ms/step - loss: 0.1759 - accuracy: 0.9866 - val_loss: 0.1757 - val_accuracy: 0.9979
# Epoch 7/10
# 59/59 [==============================] - 6s 108ms/step - loss: 0.1397 - accuracy: 0.9919 - val_loss: 0.1278 - val_accuracy: 0.9914
# Epoch 8/10
# 59/59 [==============================] - 6s 109ms/step - loss: 0.1004 - accuracy: 0.9984 - val_loss: 0.0965 - val_accuracy: 0.9979
# Epoch 9/10
# 59/59 [==============================] - 7s 112ms/step - loss: 0.0754 - accuracy: 0.9989 - val_loss: 0.0750 - val_accuracy: 1.0000
# Epoch 10/10
# 59/59 [==============================] - 7s 111ms/step - loss: 0.0617 - accuracy: 0.9995 - val_loss: 0.0636 - val_accuracy: 1.0000
# Score for Fold 1: loss of 0.06361096352338791; accuracy of 100.0%
# 15/15 [==============================] - 1s 13ms/step
# Sample 1 - Probabilities for each class:
# Class 0: Probability - 0.0001
# Class 1: Probability - 0.0154
# Class 2: Probability - 0.0001
# Class 3: Probability - 0.0001
# Class 4: Probability - 0.0001
# Class 5: Probability - 0.0168
# Class 6: Probability - 0.9674
# Sample 2 - Probabilities for each class:
# Class 0: Probability - 0.0146
# Class 1: Probability - 0.9406
# Class 2: Probability - 0.0193
# Class 3: Probability - 0.0100
# Class 4: Probability - 0.0022
# Class 5: Probability - 0.0129
# Class 6: Probability - 0.0004
# Sample 3 - Probabilities for each class:
# Class 0: Probability - 0.0231
# Class 1: Probability - 0.0289
# Class 2: Probability - 0.0027
# Class 3: Probability - 0.0001
# Class 4: Probability - 0.9343
# Class 5: Probability - 0.0023
# Class 6: Probability - 0.0086
# Sample 4 - Probabilities for each class:
# Class 0: Probability - 0.0448
# Class 1: Probability - 0.0590
# Class 2: Probability - 0.0042
# Class 3: Probability - 0.0006
# Class 4: Probability - 0.8136
# Class 5: Probability - 0.0140
# Class 6: Probability - 0.0637
# Sample 5 - Probabilities for each class:
# Class 0: Probability - 0.0022
# Class 1: Probability - 0.0052
# Class 2: Probability - 0.0168
# Class 3: Probability - 0.9758
# Class 4: Probability - 0.0000
# Class 5: Probability - 0.0000
# Class 6: Probability - 0.0000
# Sample 6 - Probabilities for each class:
# Class 0: Probability - 0.0006
# Class 1: Probability - 0.0177
# Class 2: Probability - 0.9689
# Class 3: Probability - 0.0060
# Class 4: Probability - 0.0034
# Class 5: Probability - 0.0015
# Class 6: Probability - 0.0019
# Sample 7 - Probabilities for each class:
# Class 0: Probability - 0.0002
# Class 1: Probability - 0.0613
# Class 2: Probability - 0.0012
# Class 3: Probability - 0.0001
# Class 4: Probability - 0.0018
# Class 5: Probability - 0.9291
# Class 6: Probability - 0.0064
# Sample 8 - Probabilities for each class:
# Class 0: Probability - 0.0042
# Class 1: Probability - 0.0044
# Class 2: Probability - 0.0001
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.9760
# Class 5: Probability - 0.0038
# Class 6: Probability - 0.0115
# Sample 9 - Probabilities for each class:
# Class 0: Probability - 0.9624
# Class 1: Probability - 0.0009
# Class 2: Probability - 0.0135
# Class 3: Probability - 0.0137
# Class 4: Probability - 0.0093
# Class 5: Probability - 0.0000
# Class 6: Probability - 0.0002
# Sample 10 - Probabilities for each class:
# Class 0: Probability - 0.0083
# Class 1: Probability - 0.0028
# Class 2: Probability - 0.9555
# Class 3: Probability - 0.0328
# Class 4: Probability - 0.0004
# Class 5: Probability - 0.0002
# Class 6: Probability - 0.0000
# Sample 11 - Probabilities for each class:
# Class 0: Probability - 0.0004
# Class 1: Probability - 0.0012
# Class 2: Probability - 0.0166
# Class 3: Probability - 0.9817
# Class 4: Probability - 0.0000
# Class 5: Probability - 0.0000
# Class 6: Probability - 0.0001
# Sample 12 - Probabilities for each class:
# Class 0: Probability - 0.0004
# Class 1: Probability - 0.0005
# Class 2: Probability - 0.0070
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.9896
# Class 5: Probability - 0.0024
# Class 6: Probability - 0.0000
# Sample 13 - Probabilities for each class:
# Class 0: Probability - 0.0003
# Class 1: Probability - 0.0051
# Class 2: Probability - 0.0040
# Class 3: Probability - 0.9907
# Class 4: Probability - 0.0000
# Class 5: Probability - 0.0000
# Class 6: Probability - 0.0000
# Sample 14 - Probabilities for each class:
# Class 0: Probability - 0.0000
# Class 1: Probability - 0.0132
# Class 2: Probability - 0.9861
# Class 3: Probability - 0.0002
# Class 4: Probability - 0.0004
# Class 5: Probability - 0.0001
# Class 6: Probability - 0.0000
# Sample 15 - Probabilities for each class:
# Class 0: Probability - 0.0001
# Class 1: Probability - 0.0170
# Class 2: Probability - 0.0000
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.0016
# Class 5: Probability - 0.0270
# Class 6: Probability - 0.9542
# Sample 16 - Probabilities for each class:
# Class 0: Probability - 0.0004
# Class 1: Probability - 0.0005
# Class 2: Probability - 0.0070
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.9896
# Class 5: Probability - 0.0024
# Class 6: Probability - 0.0000
# Sample 17 - Probabilities for each class:
# Class 0: Probability - 0.0004
# Class 1: Probability - 0.0000
# Class 2: Probability - 0.0008
# Class 3: Probability - 0.9986
# Class 4: Probability - 0.0000
# Class 5: Probability - 0.0000
# Class 6: Probability - 0.0001
# Sample 18 - Probabilities for each class:
# Class 0: Probability - 0.0005
# Class 1: Probability - 0.0012
# Class 2: Probability - 0.0071
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.9889
# Class 5: Probability - 0.0004
# Class 6: Probability - 0.0019
# Sample 19 - Probabilities for each class:
# Class 0: Probability - 0.9280
# Class 1: Probability - 0.0134
# Class 2: Probability - 0.0059
# Class 3: Probability - 0.0455
# Class 4: Probability - 0.0025
# Class 5: Probability - 0.0018
# Class 6: Probability - 0.0030
# Sample 20 - Probabilities for each class:
# Class 0: Probability - 0.0053
# Class 1: Probability - 0.0001
# Class 2: Probability - 0.0000
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.9926
# Class 5: Probability - 0.0009
# Class 6: Probability - 0.0010
# Sample 21 - Probabilities for each class:
# Class 0: Probability - 0.0002
# Class 1: Probability - 0.0829
# Class 2: Probability - 0.0047
# Class 3: Probability - 0.0001
# Class 4: Probability - 0.0081
# Class 5: Probability - 0.8877
# Class 6: Probability - 0.0163
# Sample 22 - Probabilities for each class:
# Class 0: Probability - 0.0134
# Class 1: Probability - 0.0122
# Class 2: Probability - 0.0005
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.9354
# Class 5: Probability - 0.0080
# Class 6: Probability - 0.0305
# Sample 23 - Probabilities for each class:
# Class 0: Probability - 0.0157
# Class 1: Probability - 0.0022
# Class 2: Probability - 0.0003
# Class 3: Probability - 0.0001
# Class 4: Probability - 0.0049
# Class 5: Probability - 0.9596
# Class 6: Probability - 0.0173
# Sample 24 - Probabilities for each class:
# Class 0: Probability - 0.0088
# Class 1: Probability - 0.8532
# Class 2: Probability - 0.0564
# Class 3: Probability - 0.0254
# Class 4: Probability - 0.0045
# Class 5: Probability - 0.0320
# Class 6: Probability - 0.0198
# Sample 25 - Probabilities for each class:
# Class 0: Probability - 0.0000
# Class 1: Probability - 0.0071
# Class 2: Probability - 0.0008
# Class 3: Probability - 0.0001
# Class 4: Probability - 0.0000
# Class 5: Probability - 0.9745
# Class 6: Probability - 0.0175
# Sample 26 - Probabilities for each class:
# Class 0: Probability - 0.0010
# Class 1: Probability - 0.0001
# Class 2: Probability - 0.0006
# Class 3: Probability - 0.9979
# Class 4: Probability - 0.0000
# Class 5: Probability - 0.0000
# Class 6: Probability - 0.0004
# Sample 27 - Probabilities for each class:
# Class 0: Probability - 0.0067
# Class 1: Probability - 0.9534
# Class 2: Probability - 0.0080
# Class 3: Probability - 0.0068
# Class 4: Probability - 0.0002
# Class 5: Probability - 0.0139
# Class 6: Probability - 0.0110
# Sample 28 - Probabilities for each class:
# Class 0: Probability - 0.0013
# Class 1: Probability - 0.0092
# Class 2: Probability - 0.9671
# Class 3: Probability - 0.0073
# Class 4: Probability - 0.0092
# Class 5: Probability - 0.0005
# Class 6: Probability - 0.0054
# Sample 29 - Probabilities for each class:
# Class 0: Probability - 0.0001
# Class 1: Probability - 0.0018
# Class 2: Probability - 0.9828
# Class 3: Probability - 0.0152
# Class 4: Probability - 0.0000
# Class 5: Probability - 0.0001
# Class 6: Probability - 0.0000
# Sample 30 - Probabilities for each class:
# Class 0: Probability - 0.0037
# Class 1: Probability - 0.0335
# Class 2: Probability - 0.0002
# Class 3: Probability - 0.0016
# Class 4: Probability - 0.0004
# Class 5: Probability - 0.0262
# Class 6: Probability - 0.9344
# Sample 31 - Probabilities for each class:
# Class 0: Probability - 0.9768
# Class 1: Probability - 0.0005
# Class 2: Probability - 0.0080
# Class 3: Probability - 0.0122
# Class 4: Probability - 0.0022
# Class 5: Probability - 0.0001
# Class 6: Probability - 0.0001
# Sample 32 - Probabilities for each class:
# Class 0: Probability - 0.0134
# Class 1: Probability - 0.9468
# Class 2: Probability - 0.0054
# Class 3: Probability - 0.0029
# Class 4: Probability - 0.0003
# Class 5: Probability - 0.0194
# Class 6: Probability - 0.0118
# Sample 33 - Probabilities for each class:
# Class 0: Probability - 0.0005
# Class 1: Probability - 0.0012
# Class 2: Probability - 0.0071
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.9889
# Class 5: Probability - 0.0004
# Class 6: Probability - 0.0019
# Sample 34 - Probabilities for each class:
# Class 0: Probability - 0.0001
# Class 1: Probability - 0.0018
# Class 2: Probability - 0.9828
# Class 3: Probability - 0.0152
# Class 4: Probability - 0.0000
# Class 5: Probability - 0.0001
# Class 6: Probability - 0.0000
# Sample 35 - Probabilities for each class:
# Class 0: Probability - 0.0000
# Class 1: Probability - 0.0132
# Class 2: Probability - 0.9861
# Class 3: Probability - 0.0002
# Class 4: Probability - 0.0004
# Class 5: Probability - 0.0001
# Class 6: Probability - 0.0000
# Sample 36 - Probabilities for each class:
# Class 0: Probability - 0.0054
# Class 1: Probability - 0.0035
# Class 2: Probability - 0.0000
# Class 3: Probability - 0.9864
# Class 4: Probability - 0.0000
# Class 5: Probability - 0.0001
# Class 6: Probability - 0.0046
# Sample 37 - Probabilities for each class:
# Class 0: Probability - 0.9318
# Class 1: Probability - 0.0130
# Class 2: Probability - 0.0021
# Class 3: Probability - 0.0273
# Class 4: Probability - 0.0008
# Class 5: Probability - 0.0214
# Class 6: Probability - 0.0036
# Sample 38 - Probabilities for each class:
# Class 0: Probability - 0.0001
# Class 1: Probability - 0.0219
# Class 2: Probability - 0.0013
# Class 3: Probability - 0.0016
# Class 4: Probability - 0.0001
# Class 5: Probability - 0.0098
# Class 6: Probability - 0.9652
# Sample 39 - Probabilities for each class:
# Class 0: Probability - 0.9276
# Class 1: Probability - 0.0236
# Class 2: Probability - 0.0048
# Class 3: Probability - 0.0327
# Class 4: Probability - 0.0035
# Class 5: Probability - 0.0050
# Class 6: Probability - 0.0029
# Sample 40 - Probabilities for each class:
# Class 0: Probability - 0.0088
# Class 1: Probability - 0.8532
# Class 2: Probability - 0.0564
# Class 3: Probability - 0.0254
# Class 4: Probability - 0.0045
# Class 5: Probability - 0.0320
# Class 6: Probability - 0.0198
# Sample 41 - Probabilities for each class:
# Class 0: Probability - 0.0000
# Class 1: Probability - 0.0088
# Class 2: Probability - 0.0000
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.0004
# Class 5: Probability - 0.0118
# Class 6: Probability - 0.9790
# Sample 42 - Probabilities for each class:
# Class 0: Probability - 0.0458
# Class 1: Probability - 0.0153
# Class 2: Probability - 0.0287
# Class 3: Probability - 0.9076
# Class 4: Probability - 0.0002
# Class 5: Probability - 0.0009
# Class 6: Probability - 0.0015
# Sample 43 - Probabilities for each class:
# Class 0: Probability - 0.0001
# Class 1: Probability - 0.0604
# Class 2: Probability - 0.9175
# Class 3: Probability - 0.0155
# Class 4: Probability - 0.0009
# Class 5: Probability - 0.0010
# Class 6: Probability - 0.0046
# Sample 44 - Probabilities for each class:
# Class 0: Probability - 0.0080
# Class 1: Probability - 0.6484
# Class 2: Probability - 0.0894
# Class 3: Probability - 0.0699
# Class 4: Probability - 0.0052
# Class 5: Probability - 0.0938
# Class 6: Probability - 0.0853
# Sample 45 - Probabilities for each class:
# Class 0: Probability - 0.0134
# Class 1: Probability - 0.0122
# Class 2: Probability - 0.0005
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.9354
# Class 5: Probability - 0.0080
# Class 6: Probability - 0.0305
# Sample 46 - Probabilities for each class:
# Class 0: Probability - 0.0013
# Class 1: Probability - 0.0092
# Class 2: Probability - 0.9671
# Class 3: Probability - 0.0073
# Class 4: Probability - 0.0092
# Class 5: Probability - 0.0005
# Class 6: Probability - 0.0054
# Sample 47 - Probabilities for each class:
# Class 0: Probability - 0.0325
# Class 1: Probability - 0.0044
# Class 2: Probability - 0.0001
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.9400
# Class 5: Probability - 0.0138
# Class 6: Probability - 0.0091
# Sample 48 - Probabilities for each class:
# Class 0: Probability - 0.9904
# Class 1: Probability - 0.0021
# Class 2: Probability - 0.0001
# Class 3: Probability - 0.0046
# Class 4: Probability - 0.0004
# Class 5: Probability - 0.0009
# Class 6: Probability - 0.0015
# Sample 49 - Probabilities for each class:
# Class 0: Probability - 0.0070
# Class 1: Probability - 0.9784
# Class 2: Probability - 0.0040
# Class 3: Probability - 0.0024
# Class 4: Probability - 0.0015
# Class 5: Probability - 0.0062
# Class 6: Probability - 0.0004
# Sample 50 - Probabilities for each class:
# Class 0: Probability - 0.0000
# Class 1: Probability - 0.0049
# Class 2: Probability - 0.9926
# Class 3: Probability - 0.0016
# Class 4: Probability - 0.0001
# Class 5: Probability - 0.0008
# Class 6: Probability - 0.0000
# Sample 51 - Probabilities for each class:
# Class 0: Probability - 0.0018
# Class 1: Probability - 0.0011
# Class 2: Probability - 0.0009
# Class 3: Probability - 0.9962
# Class 4: Probability - 0.0000
# Class 5: Probability - 0.0000
# Class 6: Probability - 0.0001
# Sample 52 - Probabilities for each class:
# Class 0: Probability - 0.0088
# Class 1: Probability - 0.8532
# Class 2: Probability - 0.0564
# Class 3: Probability - 0.0254
# Class 4: Probability - 0.0045
# Class 5: Probability - 0.0320
# Class 6: Probability - 0.0198
# Sample 53 - Probabilities for each class:
# Class 0: Probability - 0.0001
# Class 1: Probability - 0.0082
# Class 2: Probability - 0.9877
# Class 3: Probability - 0.0040
# Class 4: Probability - 0.0000
# Class 5: Probability - 0.0000
# Class 6: Probability - 0.0000
# Sample 54 - Probabilities for each class:
# Class 0: Probability - 0.9579
# Class 1: Probability - 0.0189
# Class 2: Probability - 0.0003
# Class 3: Probability - 0.0147
# Class 4: Probability - 0.0003
# Class 5: Probability - 0.0019
# Class 6: Probability - 0.0059
# Sample 55 - Probabilities for each class:
# Class 0: Probability - 0.0064
# Class 1: Probability - 0.0197
# Class 2: Probability - 0.0458
# Class 3: Probability - 0.0061
# Class 4: Probability - 0.0199
# Class 5: Probability - 0.0089
# Class 6: Probability - 0.8932
# Sample 56 - Probabilities for each class:
# Class 0: Probability - 0.8585
# Class 1: Probability - 0.0329
# Class 2: Probability - 0.0146
# Class 3: Probability - 0.0070
# Class 4: Probability - 0.0231
# Class 5: Probability - 0.0638
# Class 6: Probability - 0.0002
# Sample 57 - Probabilities for each class:
# Class 0: Probability - 0.9276
# Class 1: Probability - 0.0236
# Class 2: Probability - 0.0048
# Class 3: Probability - 0.0327
# Class 4: Probability - 0.0035
# Class 5: Probability - 0.0050
# Class 6: Probability - 0.0029
# Sample 58 - Probabilities for each class:
# Class 0: Probability - 0.0010
# Class 1: Probability - 0.0001
# Class 2: Probability - 0.0006
# Class 3: Probability - 0.9979
# Class 4: Probability - 0.0000
# Class 5: Probability - 0.0000
# Class 6: Probability - 0.0004
# Sample 59 - Probabilities for each class:
# Class 0: Probability - 0.9269
# Class 1: Probability - 0.0004
# Class 2: Probability - 0.0044
# Class 3: Probability - 0.0671
# Class 4: Probability - 0.0007
# Class 5: Probability - 0.0000
# Class 6: Probability - 0.0005
# Sample 60 - Probabilities for each class:
# Class 0: Probability - 0.0001
# Class 1: Probability - 0.0209
# Class 2: Probability - 0.0000
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.0014
# Class 5: Probability - 0.0128
# Class 6: Probability - 0.9648
# Sample 61 - Probabilities for each class:
# Class 0: Probability - 0.0007
# Class 1: Probability - 0.0077
# Class 2: Probability - 0.9439
# Class 3: Probability - 0.0472
# Class 4: Probability - 0.0001
# Class 5: Probability - 0.0004
# Class 6: Probability - 0.0000
# Sample 62 - Probabilities for each class:
# Class 0: Probability - 0.0006
# Class 1: Probability - 0.0177
# Class 2: Probability - 0.9689
# Class 3: Probability - 0.0060
# Class 4: Probability - 0.0034
# Class 5: Probability - 0.0015
# Class 6: Probability - 0.0019
# Sample 63 - Probabilities for each class:
# Class 0: Probability - 0.0215
# Class 1: Probability - 0.0136
# Class 2: Probability - 0.0016
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.9204
# Class 5: Probability - 0.0203
# Class 6: Probability - 0.0224
# Sample 64 - Probabilities for each class:
# Class 0: Probability - 0.0000
# Class 1: Probability - 0.9687
# Class 2: Probability - 0.0114
# Class 3: Probability - 0.0031
# Class 4: Probability - 0.0002
# Class 5: Probability - 0.0004
# Class 6: Probability - 0.0163
# Sample 65 - Probabilities for each class:
# Class 0: Probability - 0.0025
# Class 1: Probability - 0.0002
# Class 2: Probability - 0.0045
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.9910
# Class 5: Probability - 0.0018
# Class 6: Probability - 0.0001
# Sample 66 - Probabilities for each class:
# Class 0: Probability - 0.0002
# Class 1: Probability - 0.0006
# Class 2: Probability - 0.0073
# Class 3: Probability - 0.9918
# Class 4: Probability - 0.0000
# Class 5: Probability - 0.0000
# Class 6: Probability - 0.0002
# Sample 67 - Probabilities for each class:
# Class 0: Probability - 0.0001
# Class 1: Probability - 0.0219
# Class 2: Probability - 0.0013
# Class 3: Probability - 0.0016
# Class 4: Probability - 0.0001
# Class 5: Probability - 0.0098
# Class 6: Probability - 0.9652
# Sample 68 - Probabilities for each class:
# Class 0: Probability - 0.9858
# Class 1: Probability - 0.0078
# Class 2: Probability - 0.0016
# Class 3: Probability - 0.0034
# Class 4: Probability - 0.0008
# Class 5: Probability - 0.0006
# Class 6: Probability - 0.0000
# Sample 69 - Probabilities for each class:
# Class 0: Probability - 0.0054
# Class 1: Probability - 0.0102
# Class 2: Probability - 0.0213
# Class 3: Probability - 0.9631
# Class 4: Probability - 0.0000
# Class 5: Probability - 0.0000
# Class 6: Probability - 0.0001
# Sample 70 - Probabilities for each class:
# Class 0: Probability - 0.9741
# Class 1: Probability - 0.0054
# Class 2: Probability - 0.0005
# Class 3: Probability - 0.0182
# Class 4: Probability - 0.0004
# Class 5: Probability - 0.0006
# Class 6: Probability - 0.0009
# Sample 71 - Probabilities for each class:
# Class 0: Probability - 0.1330
# Class 1: Probability - 0.0701
# Class 2: Probability - 0.1222
# Class 3: Probability - 0.6481
# Class 4: Probability - 0.0017
# Class 5: Probability - 0.0201
# Class 6: Probability - 0.0048
# Sample 72 - Probabilities for each class:
# Class 0: Probability - 0.0080
# Class 1: Probability - 0.6484
# Class 2: Probability - 0.0894
# Class 3: Probability - 0.0699
# Class 4: Probability - 0.0052
# Class 5: Probability - 0.0938
# Class 6: Probability - 0.0853
# Sample 73 - Probabilities for each class:
# Class 0: Probability - 0.9614
# Class 1: Probability - 0.0048
# Class 2: Probability - 0.0015
# Class 3: Probability - 0.0275
# Class 4: Probability - 0.0005
# Class 5: Probability - 0.0029
# Class 6: Probability - 0.0013
# Sample 74 - Probabilities for each class:
# Class 0: Probability - 0.0000
# Class 1: Probability - 0.0022
# Class 2: Probability - 0.0000
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.0000
# Class 5: Probability - 0.9978
# Class 6: Probability - 0.0000
# Sample 75 - Probabilities for each class:
# Class 0: Probability - 0.0043
# Class 1: Probability - 0.0022
# Class 2: Probability - 0.9838
# Class 3: Probability - 0.0087
# Class 4: Probability - 0.0009
# Class 5: Probability - 0.0001
# Class 6: Probability - 0.0000
# Sample 76 - Probabilities for each class:
# Class 0: Probability - 0.1051
# Class 1: Probability - 0.0326
# Class 2: Probability - 0.0417
# Class 3: Probability - 0.0044
# Class 4: Probability - 0.7896
# Class 5: Probability - 0.0149
# Class 6: Probability - 0.0117
# Sample 77 - Probabilities for each class:
# Class 0: Probability - 0.0223
# Class 1: Probability - 0.9339
# Class 2: Probability - 0.0153
# Class 3: Probability - 0.0100
# Class 4: Probability - 0.0012
# Class 5: Probability - 0.0171
# Class 6: Probability - 0.0002
# Sample 78 - Probabilities for each class:
# Class 0: Probability - 0.0037
# Class 1: Probability - 0.0335
# Class 2: Probability - 0.0002
# Class 3: Probability - 0.0016
# Class 4: Probability - 0.0004
# Class 5: Probability - 0.0262
# Class 6: Probability - 0.9344
# Sample 79 - Probabilities for each class:
# Class 0: Probability - 0.0000
# Class 1: Probability - 0.0164
# Class 2: Probability - 0.0000
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.0002
# Class 5: Probability - 0.0063
# Class 6: Probability - 0.9771
# Sample 80 - Probabilities for each class:
# Class 0: Probability - 0.0000
# Class 1: Probability - 0.0022
# Class 2: Probability - 0.0000
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.0000
# Class 5: Probability - 0.9978
# Class 6: Probability - 0.0000
# Sample 81 - Probabilities for each class:
# Class 0: Probability - 0.0018
# Class 1: Probability - 0.0011
# Class 2: Probability - 0.0009
# Class 3: Probability - 0.9962
# Class 4: Probability - 0.0000
# Class 5: Probability - 0.0000
# Class 6: Probability - 0.0001
# Sample 82 - Probabilities for each class:
# Class 0: Probability - 0.0147
# Class 1: Probability - 0.0939
# Class 2: Probability - 0.0213
# Class 3: Probability - 0.0009
# Class 4: Probability - 0.8547
# Class 5: Probability - 0.0084
# Class 6: Probability - 0.0059
# Sample 83 - Probabilities for each class:
# Class 0: Probability - 0.9742
# Class 1: Probability - 0.0082
# Class 2: Probability - 0.0003
# Class 3: Probability - 0.0070
# Class 4: Probability - 0.0013
# Class 5: Probability - 0.0031
# Class 6: Probability - 0.0059
# Sample 84 - Probabilities for each class:
# Class 0: Probability - 0.0047
# Class 1: Probability - 0.0051
# Class 2: Probability - 0.0001
# Class 3: Probability - 0.9860
# Class 4: Probability - 0.0000
# Class 5: Probability - 0.0001
# Class 6: Probability - 0.0040
# Sample 85 - Probabilities for each class:
# Class 0: Probability - 0.9701
# Class 1: Probability - 0.0036
# Class 2: Probability - 0.0069
# Class 3: Probability - 0.0131
# Class 4: Probability - 0.0056
# Class 5: Probability - 0.0002
# Class 6: Probability - 0.0004
# Sample 86 - Probabilities for each class:
# Class 0: Probability - 0.0002
# Class 1: Probability - 0.0189
# Class 2: Probability - 0.0015
# Class 3: Probability - 0.0052
# Class 4: Probability - 0.0000
# Class 5: Probability - 0.0072
# Class 6: Probability - 0.9670
# Sample 87 - Probabilities for each class:
# Class 0: Probability - 0.0000
# Class 1: Probability - 0.0040
# Class 2: Probability - 0.9931
# Class 3: Probability - 0.0029
# Class 4: Probability - 0.0000
# Class 5: Probability - 0.0000
# Class 6: Probability - 0.0000
# Sample 88 - Probabilities for each class:
# Class 0: Probability - 0.0001
# Class 1: Probability - 0.0088
# Class 2: Probability - 0.0000
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.0027
# Class 5: Probability - 0.0251
# Class 6: Probability - 0.9633
# Sample 89 - Probabilities for each class:
# Class 0: Probability - 0.0003
# Class 1: Probability - 0.0258
# Class 2: Probability - 0.0002
# Class 3: Probability - 0.0012
# Class 4: Probability - 0.0002
# Class 5: Probability - 0.0036
# Class 6: Probability - 0.9687
# Sample 90 - Probabilities for each class:
# Class 0: Probability - 0.0134
# Class 1: Probability - 0.0122
# Class 2: Probability - 0.0005
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.9354
# Class 5: Probability - 0.0080
# Class 6: Probability - 0.0305
# Sample 91 - Probabilities for each class:
# Class 0: Probability - 0.0002
# Class 1: Probability - 0.0066
# Class 2: Probability - 0.9663
# Class 3: Probability - 0.0266
# Class 4: Probability - 0.0001
# Class 5: Probability - 0.0001
# Class 6: Probability - 0.0001
# Sample 92 - Probabilities for each class:
# Class 0: Probability - 0.0002
# Class 1: Probability - 0.0224
# Class 2: Probability - 0.0013
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.9596
# Class 5: Probability - 0.0157
# Class 6: Probability - 0.0008
# Sample 93 - Probabilities for each class:
# Class 0: Probability - 0.0005
# Class 1: Probability - 0.0012
# Class 2: Probability - 0.0071
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.9889
# Class 5: Probability - 0.0004
# Class 6: Probability - 0.0019
# Sample 94 - Probabilities for each class:
# Class 0: Probability - 0.0025
# Class 1: Probability - 0.0381
# Class 2: Probability - 0.2519
# Class 3: Probability - 0.0002
# Class 4: Probability - 0.6786
# Class 5: Probability - 0.0021
# Class 6: Probability - 0.0264
# Sample 95 - Probabilities for each class:
# Class 0: Probability - 0.9280
# Class 1: Probability - 0.0134
# Class 2: Probability - 0.0059
# Class 3: Probability - 0.0455
# Class 4: Probability - 0.0025
# Class 5: Probability - 0.0018
# Class 6: Probability - 0.0030
# Sample 96 - Probabilities for each class:
# Class 0: Probability - 0.0004
# Class 1: Probability - 0.1094
# Class 2: Probability - 0.0045
# Class 3: Probability - 0.0002
# Class 4: Probability - 0.0068
# Class 5: Probability - 0.8363
# Class 6: Probability - 0.0424
# Sample 97 - Probabilities for each class:
# Class 0: Probability - 0.0004
# Class 1: Probability - 0.0000
# Class 2: Probability - 0.0008
# Class 3: Probability - 0.9986
# Class 4: Probability - 0.0000
# Class 5: Probability - 0.0000
# Class 6: Probability - 0.0001
# Sample 98 - Probabilities for each class:
# Class 0: Probability - 0.9845
# Class 1: Probability - 0.0045
# Class 2: Probability - 0.0000
# Class 3: Probability - 0.0093
# Class 4: Probability - 0.0001
# Class 5: Probability - 0.0004
# Class 6: Probability - 0.0013
# Sample 99 - Probabilities for each class:
# Class 0: Probability - 0.0269
# Class 1: Probability - 0.6444
# Class 2: Probability - 0.0666
# Class 3: Probability - 0.1464
# Class 4: Probability - 0.0052
# Class 5: Probability - 0.0319
# Class 6: Probability - 0.0786
# Sample 100 - Probabilities for each class:
# Class 0: Probability - 0.0000
# Class 1: Probability - 0.0040
# Class 2: Probability - 0.9931
# Class 3: Probability - 0.0029
# Class 4: Probability - 0.0000
# Class 5: Probability - 0.0000
# Class 6: Probability - 0.0000
# Sample 101 - Probabilities for each class:
# Class 0: Probability - 0.0000
# Class 1: Probability - 0.0071
# Class 2: Probability - 0.0008
# Class 3: Probability - 0.0001
# Class 4: Probability - 0.0000
# Class 5: Probability - 0.9745
# Class 6: Probability - 0.0175
# Sample 102 - Probabilities for each class:
# Class 0: Probability - 0.0000
# Class 1: Probability - 0.0241
# Class 2: Probability - 0.0019
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.0000
# Class 5: Probability - 0.9583
# Class 6: Probability - 0.0157
# Sample 103 - Probabilities for each class:
# Class 0: Probability - 0.9614
# Class 1: Probability - 0.0048
# Class 2: Probability - 0.0015
# Class 3: Probability - 0.0275
# Class 4: Probability - 0.0005
# Class 5: Probability - 0.0029
# Class 6: Probability - 0.0013
# Sample 104 - Probabilities for each class:
# Class 0: Probability - 0.9630
# Class 1: Probability - 0.0010
# Class 2: Probability - 0.0007
# Class 3: Probability - 0.0349
# Class 4: Probability - 0.0001
# Class 5: Probability - 0.0002
# Class 6: Probability - 0.0001
# Sample 105 - Probabilities for each class:
# Class 0: Probability - 0.0009
# Class 1: Probability - 0.9929
# Class 2: Probability - 0.0006
# Class 3: Probability - 0.0013
# Class 4: Probability - 0.0004
# Class 5: Probability - 0.0006
# Class 6: Probability - 0.0033
# Sample 106 - Probabilities for each class:
# Class 0: Probability - 0.9768
# Class 1: Probability - 0.0005
# Class 2: Probability - 0.0080
# Class 3: Probability - 0.0122
# Class 4: Probability - 0.0022
# Class 5: Probability - 0.0001
# Class 6: Probability - 0.0001
# Sample 107 - Probabilities for each class:
# Class 0: Probability - 0.0021
# Class 1: Probability - 0.8077
# Class 2: Probability - 0.0673
# Class 3: Probability - 0.0272
# Class 4: Probability - 0.0029
# Class 5: Probability - 0.0656
# Class 6: Probability - 0.0272
# Sample 108 - Probabilities for each class:
# Class 0: Probability - 0.0095
# Class 1: Probability - 0.0016
# Class 2: Probability - 0.0320
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.9533
# Class 5: Probability - 0.0035
# Class 6: Probability - 0.0000
# Sample 109 - Probabilities for each class:
# Class 0: Probability - 0.0000
# Class 1: Probability - 0.0141
# Class 2: Probability - 0.0000
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.0003
# Class 5: Probability - 0.0072
# Class 6: Probability - 0.9784
# Sample 110 - Probabilities for each class:
# Class 0: Probability - 0.9953
# Class 1: Probability - 0.0028
# Class 2: Probability - 0.0001
# Class 3: Probability - 0.0003
# Class 4: Probability - 0.0013
# Class 5: Probability - 0.0003
# Class 6: Probability - 0.0000
# Sample 111 - Probabilities for each class:
# Class 0: Probability - 0.0001
# Class 1: Probability - 0.0073
# Class 2: Probability - 0.0025
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.9866
# Class 5: Probability - 0.0032
# Class 6: Probability - 0.0003
# Sample 112 - Probabilities for each class:
# Class 0: Probability - 0.0056
# Class 1: Probability - 0.0273
# Class 2: Probability - 0.7768
# Class 3: Probability - 0.1558
# Class 4: Probability - 0.0008
# Class 5: Probability - 0.0140
# Class 6: Probability - 0.0196
# Sample 113 - Probabilities for each class:
# Class 0: Probability - 0.0004
# Class 1: Probability - 0.0497
# Class 2: Probability - 0.0004
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.9159
# Class 5: Probability - 0.0297
# Class 6: Probability - 0.0040
# Sample 114 - Probabilities for each class:
# Class 0: Probability - 0.0002
# Class 1: Probability - 0.0012
# Class 2: Probability - 0.0055
# Class 3: Probability - 0.9931
# Class 4: Probability - 0.0000
# Class 5: Probability - 0.0000
# Class 6: Probability - 0.0000
# Sample 115 - Probabilities for each class:
# Class 0: Probability - 0.0025
# Class 1: Probability - 0.0002
# Class 2: Probability - 0.0045
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.9910
# Class 5: Probability - 0.0018
# Class 6: Probability - 0.0001
# Sample 116 - Probabilities for each class:
# Class 0: Probability - 0.0034
# Class 1: Probability - 0.0026
# Class 2: Probability - 0.0003
# Class 3: Probability - 0.9931
# Class 4: Probability - 0.0000
# Class 5: Probability - 0.0001
# Class 6: Probability - 0.0005
# Sample 117 - Probabilities for each class:
# Class 0: Probability - 0.0001
# Class 1: Probability - 0.0012
# Class 2: Probability - 0.0000
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.0005
# Class 5: Probability - 0.9982
# Class 6: Probability - 0.0000
# Sample 118 - Probabilities for each class:
# Class 0: Probability - 0.0003
# Class 1: Probability - 0.0258
# Class 2: Probability - 0.0002
# Class 3: Probability - 0.0012
# Class 4: Probability - 0.0002
# Class 5: Probability - 0.0036
# Class 6: Probability - 0.9687
# Sample 119 - Probabilities for each class:
# Class 0: Probability - 0.0003
# Class 1: Probability - 0.9914
# Class 2: Probability - 0.0011
# Class 3: Probability - 0.0037
# Class 4: Probability - 0.0002
# Class 5: Probability - 0.0000
# Class 6: Probability - 0.0031
# Sample 120 - Probabilities for each class:
# Class 0: Probability - 0.0003
# Class 1: Probability - 0.0996
# Class 2: Probability - 0.0009
# Class 3: Probability - 0.0001
# Class 4: Probability - 0.0048
# Class 5: Probability - 0.8789
# Class 6: Probability - 0.0156
# Sample 121 - Probabilities for each class:
# Class 0: Probability - 0.0022
# Class 1: Probability - 0.0052
# Class 2: Probability - 0.0168
# Class 3: Probability - 0.9758
# Class 4: Probability - 0.0000
# Class 5: Probability - 0.0000
# Class 6: Probability - 0.0000
# Sample 122 - Probabilities for each class:
# Class 0: Probability - 0.9858
# Class 1: Probability - 0.0078
# Class 2: Probability - 0.0016
# Class 3: Probability - 0.0034
# Class 4: Probability - 0.0008
# Class 5: Probability - 0.0006
# Class 6: Probability - 0.0000
# Sample 123 - Probabilities for each class:
# Class 0: Probability - 0.0117
# Class 1: Probability - 0.0147
# Class 2: Probability - 0.9298
# Class 3: Probability - 0.0432
# Class 4: Probability - 0.0005
# Class 5: Probability - 0.0000
# Class 6: Probability - 0.0000
# Sample 124 - Probabilities for each class:
# Class 0: Probability - 0.0021
# Class 1: Probability - 0.8077
# Class 2: Probability - 0.0673
# Class 3: Probability - 0.0272
# Class 4: Probability - 0.0029
# Class 5: Probability - 0.0656
# Class 6: Probability - 0.0272
# Sample 125 - Probabilities for each class:
# Class 0: Probability - 0.0001
# Class 1: Probability - 0.0088
# Class 2: Probability - 0.0000
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.0027
# Class 5: Probability - 0.0251
# Class 6: Probability - 0.9633
# Sample 126 - Probabilities for each class:
# Class 0: Probability - 0.0000
# Class 1: Probability - 0.0019
# Class 2: Probability - 0.9909
# Class 3: Probability - 0.0072
# Class 4: Probability - 0.0000
# Class 5: Probability - 0.0000
# Class 6: Probability - 0.0000
# Sample 127 - Probabilities for each class:
# Class 0: Probability - 0.9851
# Class 1: Probability - 0.0014
# Class 2: Probability - 0.0034
# Class 3: Probability - 0.0072
# Class 4: Probability - 0.0025
# Class 5: Probability - 0.0001
# Class 6: Probability - 0.0003
# Sample 128 - Probabilities for each class:
# Class 0: Probability - 0.9624
# Class 1: Probability - 0.0009
# Class 2: Probability - 0.0135
# Class 3: Probability - 0.0137
# Class 4: Probability - 0.0093
# Class 5: Probability - 0.0000
# Class 6: Probability - 0.0002
# Sample 129 - Probabilities for each class:
# Class 0: Probability - 0.0025
# Class 1: Probability - 0.0002
# Class 2: Probability - 0.0045
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.9910
# Class 5: Probability - 0.0018
# Class 6: Probability - 0.0001
# Sample 130 - Probabilities for each class:
# Class 0: Probability - 0.0116
# Class 1: Probability - 0.0159
# Class 2: Probability - 0.0007
# Class 3: Probability - 0.0020
# Class 4: Probability - 0.0007
# Class 5: Probability - 0.8473
# Class 6: Probability - 0.1219
# Sample 131 - Probabilities for each class:
# Class 0: Probability - 0.9318
# Class 1: Probability - 0.0130
# Class 2: Probability - 0.0021
# Class 3: Probability - 0.0273
# Class 4: Probability - 0.0008
# Class 5: Probability - 0.0214
# Class 6: Probability - 0.0036
# Sample 132 - Probabilities for each class:
# Class 0: Probability - 0.0025
# Class 1: Probability - 0.0002
# Class 2: Probability - 0.0045
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.9910
# Class 5: Probability - 0.0018
# Class 6: Probability - 0.0001
# Sample 133 - Probabilities for each class:
# Class 0: Probability - 0.0134
# Class 1: Probability - 0.9468
# Class 2: Probability - 0.0054
# Class 3: Probability - 0.0029
# Class 4: Probability - 0.0003
# Class 5: Probability - 0.0194
# Class 6: Probability - 0.0118
# Sample 134 - Probabilities for each class:
# Class 0: Probability - 0.0002
# Class 1: Probability - 0.0189
# Class 2: Probability - 0.0015
# Class 3: Probability - 0.0052
# Class 4: Probability - 0.0000
# Class 5: Probability - 0.0072
# Class 6: Probability - 0.9670
# Sample 135 - Probabilities for each class:
# Class 0: Probability - 0.0054
# Class 1: Probability - 0.0102
# Class 2: Probability - 0.0213
# Class 3: Probability - 0.9631
# Class 4: Probability - 0.0000
# Class 5: Probability - 0.0000
# Class 6: Probability - 0.0001
# Sample 136 - Probabilities for each class:
# Class 0: Probability - 0.0223
# Class 1: Probability - 0.9339
# Class 2: Probability - 0.0153
# Class 3: Probability - 0.0100
# Class 4: Probability - 0.0012
# Class 5: Probability - 0.0171
# Class 6: Probability - 0.0002
# Sample 137 - Probabilities for each class:
# Class 0: Probability - 0.0147
# Class 1: Probability - 0.0939
# Class 2: Probability - 0.0213
# Class 3: Probability - 0.0009
# Class 4: Probability - 0.8547
# Class 5: Probability - 0.0084
# Class 6: Probability - 0.0059
# Sample 138 - Probabilities for each class:
# Class 0: Probability - 0.0002
# Class 1: Probability - 0.0012
# Class 2: Probability - 0.0055
# Class 3: Probability - 0.9931
# Class 4: Probability - 0.0000
# Class 5: Probability - 0.0000
# Class 6: Probability - 0.0000
# Sample 139 - Probabilities for each class:
# Class 0: Probability - 0.0080
# Class 1: Probability - 0.6484
# Class 2: Probability - 0.0894
# Class 3: Probability - 0.0699
# Class 4: Probability - 0.0052
# Class 5: Probability - 0.0938
# Class 6: Probability - 0.0853
# Sample 140 - Probabilities for each class:
# Class 0: Probability - 0.0001
# Class 1: Probability - 0.0055
# Class 2: Probability - 0.0002
# Class 3: Probability - 0.0002
# Class 4: Probability - 0.0000
# Class 5: Probability - 0.9814
# Class 6: Probability - 0.0127
# Sample 141 - Probabilities for each class:
# Class 0: Probability - 0.0001
# Class 1: Probability - 0.0257
# Class 2: Probability - 0.0003
# Class 3: Probability - 0.0005
# Class 4: Probability - 0.0002
# Class 5: Probability - 0.0044
# Class 6: Probability - 0.9688
# Sample 142 - Probabilities for each class:
# Class 0: Probability - 0.0000
# Class 1: Probability - 0.9687
# Class 2: Probability - 0.0114
# Class 3: Probability - 0.0031
# Class 4: Probability - 0.0002
# Class 5: Probability - 0.0004
# Class 6: Probability - 0.0163
# Sample 143 - Probabilities for each class:
# Class 0: Probability - 0.0000
# Class 1: Probability - 0.0048
# Class 2: Probability - 0.0090
# Class 3: Probability - 0.9862
# Class 4: Probability - 0.0000
# Class 5: Probability - 0.0000
# Class 6: Probability - 0.0000
# Sample 144 - Probabilities for each class:
# Class 0: Probability - 0.0516
# Class 1: Probability - 0.0314
# Class 2: Probability - 0.0063
# Class 3: Probability - 0.0007
# Class 4: Probability - 0.8809
# Class 5: Probability - 0.0130
# Class 6: Probability - 0.0161
# Sample 145 - Probabilities for each class:
# Class 0: Probability - 0.0199
# Class 1: Probability - 0.9489
# Class 2: Probability - 0.0126
# Class 3: Probability - 0.0061
# Class 4: Probability - 0.0010
# Class 5: Probability - 0.0114
# Class 6: Probability - 0.0002
# Sample 146 - Probabilities for each class:
# Class 0: Probability - 0.0000
# Class 1: Probability - 0.0011
# Class 2: Probability - 0.0000
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.0002
# Class 5: Probability - 0.9987
# Class 6: Probability - 0.0000
# Sample 147 - Probabilities for each class:
# Class 0: Probability - 0.9858
# Class 1: Probability - 0.0078
# Class 2: Probability - 0.0016
# Class 3: Probability - 0.0034
# Class 4: Probability - 0.0008
# Class 5: Probability - 0.0006
# Class 6: Probability - 0.0000
# Sample 148 - Probabilities for each class:
# Class 0: Probability - 0.0001
# Class 1: Probability - 0.0060
# Class 2: Probability - 0.0007
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.9776
# Class 5: Probability - 0.0155
# Class 6: Probability - 0.0001
# Sample 149 - Probabilities for each class:
# Class 0: Probability - 0.0000
# Class 1: Probability - 0.0215
# Class 2: Probability - 0.0012
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.9660
# Class 5: Probability - 0.0103
# Class 6: Probability - 0.0009
# Sample 150 - Probabilities for each class:
# Class 0: Probability - 0.0025
# Class 1: Probability - 0.0381
# Class 2: Probability - 0.2519
# Class 3: Probability - 0.0002
# Class 4: Probability - 0.6786
# Class 5: Probability - 0.0021
# Class 6: Probability - 0.0264
# Sample 151 - Probabilities for each class:
# Class 0: Probability - 0.0016
# Class 1: Probability - 0.0094
# Class 2: Probability - 0.0000
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.0027
# Class 5: Probability - 0.9861
# Class 6: Probability - 0.0002
# Sample 152 - Probabilities for each class:
# Class 0: Probability - 0.0006
# Class 1: Probability - 0.0202
# Class 2: Probability - 0.0000
# Class 3: Probability - 0.0010
# Class 4: Probability - 0.0000
# Class 5: Probability - 0.0037
# Class 6: Probability - 0.9744
# Sample 153 - Probabilities for each class:
# Class 0: Probability - 0.0002
# Class 1: Probability - 0.0613
# Class 2: Probability - 0.0012
# Class 3: Probability - 0.0001
# Class 4: Probability - 0.0018
# Class 5: Probability - 0.9291
# Class 6: Probability - 0.0064
# Sample 154 - Probabilities for each class:
# Class 0: Probability - 0.0022
# Class 1: Probability - 0.0009
# Class 2: Probability - 0.0001
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.0013
# Class 5: Probability - 0.9918
# Class 6: Probability - 0.0037
# Sample 155 - Probabilities for each class:
# Class 0: Probability - 0.0022
# Class 1: Probability - 0.0451
# Class 2: Probability - 0.0093
# Class 3: Probability - 0.0033
# Class 4: Probability - 0.0002
# Class 5: Probability - 0.9277
# Class 6: Probability - 0.0122
# Sample 156 - Probabilities for each class:
# Class 0: Probability - 0.0000
# Class 1: Probability - 0.0049
# Class 2: Probability - 0.9926
# Class 3: Probability - 0.0016
# Class 4: Probability - 0.0001
# Class 5: Probability - 0.0008
# Class 6: Probability - 0.0000
# Sample 157 - Probabilities for each class:
# Class 0: Probability - 0.0001
# Class 1: Probability - 0.0170
# Class 2: Probability - 0.0000
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.0016
# Class 5: Probability - 0.0270
# Class 6: Probability - 0.9542
# Sample 158 - Probabilities for each class:
# Class 0: Probability - 0.0044
# Class 1: Probability - 0.7686
# Class 2: Probability - 0.0941
# Class 3: Probability - 0.0202
# Class 4: Probability - 0.0083
# Class 5: Probability - 0.0792
# Class 6: Probability - 0.0252
# Sample 159 - Probabilities for each class:
# Class 0: Probability - 0.0012
# Class 1: Probability - 0.0441
# Class 2: Probability - 0.0042
# Class 3: Probability - 0.0046
# Class 4: Probability - 0.0014
# Class 5: Probability - 0.0049
# Class 6: Probability - 0.9396
# Sample 160 - Probabilities for each class:
# Class 0: Probability - 0.0034
# Class 1: Probability - 0.0026
# Class 2: Probability - 0.0003
# Class 3: Probability - 0.9931
# Class 4: Probability - 0.0000
# Class 5: Probability - 0.0001
# Class 6: Probability - 0.0005
# Sample 161 - Probabilities for each class:
# Class 0: Probability - 0.0004
# Class 1: Probability - 0.9929
# Class 2: Probability - 0.0004
# Class 3: Probability - 0.0011
# Class 4: Probability - 0.0007
# Class 5: Probability - 0.0000
# Class 6: Probability - 0.0044
# Sample 162 - Probabilities for each class:
# Class 0: Probability - 0.0117
# Class 1: Probability - 0.0147
# Class 2: Probability - 0.9298
# Class 3: Probability - 0.0432
# Class 4: Probability - 0.0005
# Class 5: Probability - 0.0000
# Class 6: Probability - 0.0000
# Sample 163 - Probabilities for each class:
# Class 0: Probability - 0.9276
# Class 1: Probability - 0.0236
# Class 2: Probability - 0.0048
# Class 3: Probability - 0.0327
# Class 4: Probability - 0.0035
# Class 5: Probability - 0.0050
# Class 6: Probability - 0.0029
# Sample 164 - Probabilities for each class:
# Class 0: Probability - 0.0002
# Class 1: Probability - 0.0132
# Class 2: Probability - 0.0000
# Class 3: Probability - 0.0004
# Class 4: Probability - 0.0000
# Class 5: Probability - 0.0107
# Class 6: Probability - 0.9754
# Sample 165 - Probabilities for each class:
# Class 0: Probability - 0.0001
# Class 1: Probability - 0.0170
# Class 2: Probability - 0.0000
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.0016
# Class 5: Probability - 0.0270
# Class 6: Probability - 0.9542
# Sample 166 - Probabilities for each class:
# Class 0: Probability - 0.0476
# Class 1: Probability - 0.0253
# Class 2: Probability - 0.0458
# Class 3: Probability - 0.8769
# Class 4: Probability - 0.0002
# Class 5: Probability - 0.0015
# Class 6: Probability - 0.0027
# Sample 167 - Probabilities for each class:
# Class 0: Probability - 0.0020
# Class 1: Probability - 0.0031
# Class 2: Probability - 0.9886
# Class 3: Probability - 0.0057
# Class 4: Probability - 0.0004
# Class 5: Probability - 0.0000
# Class 6: Probability - 0.0000
# Sample 168 - Probabilities for each class:
# Class 0: Probability - 0.0018
# Class 1: Probability - 0.0084
# Class 2: Probability - 0.0062
# Class 3: Probability - 0.9836
# Class 4: Probability - 0.0000
# Class 5: Probability - 0.0000
# Class 6: Probability - 0.0000
# Sample 169 - Probabilities for each class:
# Class 0: Probability - 0.0077
# Class 1: Probability - 0.0188
# Class 2: Probability - 0.0139
# Class 3: Probability - 0.9580
# Class 4: Probability - 0.0000
# Class 5: Probability - 0.0010
# Class 6: Probability - 0.0006
# Sample 170 - Probabilities for each class:
# Class 0: Probability - 0.0077
# Class 1: Probability - 0.0188
# Class 2: Probability - 0.0139
# Class 3: Probability - 0.9580
# Class 4: Probability - 0.0000
# Class 5: Probability - 0.0010
# Class 6: Probability - 0.0006
# Sample 171 - Probabilities for each class:
# Class 0: Probability - 0.9630
# Class 1: Probability - 0.0010
# Class 2: Probability - 0.0007
# Class 3: Probability - 0.0349
# Class 4: Probability - 0.0001
# Class 5: Probability - 0.0002
# Class 6: Probability - 0.0001
# Sample 172 - Probabilities for each class:
# Class 0: Probability - 0.0080
# Class 1: Probability - 0.6484
# Class 2: Probability - 0.0894
# Class 3: Probability - 0.0699
# Class 4: Probability - 0.0052
# Class 5: Probability - 0.0938
# Class 6: Probability - 0.0853
# Sample 173 - Probabilities for each class:
# Class 0: Probability - 0.0095
# Class 1: Probability - 0.0016
# Class 2: Probability - 0.0320
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.9533
# Class 5: Probability - 0.0035
# Class 6: Probability - 0.0000
# Sample 174 - Probabilities for each class:
# Class 0: Probability - 0.0034
# Class 1: Probability - 0.0026
# Class 2: Probability - 0.0003
# Class 3: Probability - 0.9931
# Class 4: Probability - 0.0000
# Class 5: Probability - 0.0001
# Class 6: Probability - 0.0005
# Sample 175 - Probabilities for each class:
# Class 0: Probability - 0.9276
# Class 1: Probability - 0.0236
# Class 2: Probability - 0.0048
# Class 3: Probability - 0.0327
# Class 4: Probability - 0.0035
# Class 5: Probability - 0.0050
# Class 6: Probability - 0.0029
# Sample 176 - Probabilities for each class:
# Class 0: Probability - 0.0000
# Class 1: Probability - 0.0082
# Class 2: Probability - 0.9787
# Class 3: Probability - 0.0131
# Class 4: Probability - 0.0000
# Class 5: Probability - 0.0000
# Class 6: Probability - 0.0000
# Sample 177 - Probabilities for each class:
# Class 0: Probability - 0.0001
# Class 1: Probability - 0.0018
# Class 2: Probability - 0.9828
# Class 3: Probability - 0.0152
# Class 4: Probability - 0.0000
# Class 5: Probability - 0.0001
# Class 6: Probability - 0.0000
# Sample 178 - Probabilities for each class:
# Class 0: Probability - 0.0000
# Class 1: Probability - 0.0019
# Class 2: Probability - 0.0000
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.0004
# Class 5: Probability - 0.9976
# Class 6: Probability - 0.0000
# Sample 179 - Probabilities for each class:
# Class 0: Probability - 0.9683
# Class 1: Probability - 0.0061
# Class 2: Probability - 0.0020
# Class 3: Probability - 0.0187
# Class 4: Probability - 0.0009
# Class 5: Probability - 0.0036
# Class 6: Probability - 0.0003
# Sample 180 - Probabilities for each class:
# Class 0: Probability - 0.0002
# Class 1: Probability - 0.0072
# Class 2: Probability - 0.9780
# Class 3: Probability - 0.0044
# Class 4: Probability - 0.0009
# Class 5: Probability - 0.0010
# Class 6: Probability - 0.0083
# Sample 181 - Probabilities for each class:
# Class 0: Probability - 0.0000
# Class 1: Probability - 0.0071
# Class 2: Probability - 0.0008
# Class 3: Probability - 0.0001
# Class 4: Probability - 0.0000
# Class 5: Probability - 0.9745
# Class 6: Probability - 0.0175
# Sample 182 - Probabilities for each class:
# Class 0: Probability - 0.0000
# Class 1: Probability - 0.9687
# Class 2: Probability - 0.0114
# Class 3: Probability - 0.0031
# Class 4: Probability - 0.0002
# Class 5: Probability - 0.0004
# Class 6: Probability - 0.0163
# Sample 183 - Probabilities for each class:
# Class 0: Probability - 0.0147
# Class 1: Probability - 0.0939
# Class 2: Probability - 0.0213
# Class 3: Probability - 0.0009
# Class 4: Probability - 0.8547
# Class 5: Probability - 0.0084
# Class 6: Probability - 0.0059
# Sample 184 - Probabilities for each class:
# Class 0: Probability - 0.0067
# Class 1: Probability - 0.8651
# Class 2: Probability - 0.0335
# Class 3: Probability - 0.0373
# Class 4: Probability - 0.0028
# Class 5: Probability - 0.0396
# Class 6: Probability - 0.0150
# ...
# Class 2: Probability - 0.9925
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.0026
# Class 5: Probability - 0.0003
# Class 6: Probability - 0.0000
# Sample 408 - Probabilities for each class:
# Class 0: Probability - 0.0269
# Class 1: Probability - 0.9607
# Class 2: Probability - 0.0002
# Class 3: Probability - 0.0026
# Class 4: Probability - 0.0003
# Class 5: Probability - 0.0092
# Class 6: Probability - 0.0002
# Sample 409 - Probabilities for each class:
# Class 0: Probability - 0.0002
# Class 1: Probability - 0.0048
# Class 2: Probability - 0.0011
# Class 3: Probability - 0.0001
# Class 4: Probability - 0.0000
# Class 5: Probability - 0.0066
# Class 6: Probability - 0.9872
# Sample 410 - Probabilities for each class:
# Class 0: Probability - 0.0002
# Class 1: Probability - 0.0013
# Class 2: Probability - 0.9980
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.0001
# Class 5: Probability - 0.0004
# Class 6: Probability - 0.0000
# Sample 411 - Probabilities for each class:
# Class 0: Probability - 0.0005
# Class 1: Probability - 0.0902
# Class 2: Probability - 0.0003
# Class 3: Probability - 0.0001
# Class 4: Probability - 0.0000
# Class 5: Probability - 0.0177
# Class 6: Probability - 0.8911
# Sample 412 - Probabilities for each class:
# Class 0: Probability - 0.0001
# Class 1: Probability - 0.0247
# Class 2: Probability - 0.0001
# Class 3: Probability - 0.9683
# Class 4: Probability - 0.0001
# Class 5: Probability - 0.0015
# Class 6: Probability - 0.0052
# Sample 413 - Probabilities for each class:
# Class 0: Probability - 0.0001
# Class 1: Probability - 0.0060
# Class 2: Probability - 0.0003
# Class 3: Probability - 0.0017
# Class 4: Probability - 0.0002
# Class 5: Probability - 0.0076
# Class 6: Probability - 0.9841
# Sample 414 - Probabilities for each class:
# Class 0: Probability - 0.0017
# Class 1: Probability - 0.0011
# Class 2: Probability - 0.0437
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.9212
# Class 5: Probability - 0.0323
# Class 6: Probability - 0.0000
# Sample 415 - Probabilities for each class:
# Class 0: Probability - 0.0008
# Class 1: Probability - 0.0080
# Class 2: Probability - 0.0001
# Class 3: Probability - 0.0007
# Class 4: Probability - 0.0000
# Class 5: Probability - 0.0013
# Class 6: Probability - 0.9890
# Sample 416 - Probabilities for each class:
# Class 0: Probability - 0.9920
# Class 1: Probability - 0.0048
# Class 2: Probability - 0.0000
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.0002
# Class 5: Probability - 0.0031
# Class 6: Probability - 0.0000
# Sample 417 - Probabilities for each class:
# Class 0: Probability - 0.0000
# Class 1: Probability - 0.0034
# Class 2: Probability - 0.0001
# Class 3: Probability - 0.9948
# Class 4: Probability - 0.0000
# Class 5: Probability - 0.0000
# Class 6: Probability - 0.0017
# Sample 418 - Probabilities for each class:
# Class 0: Probability - 0.0000
# Class 1: Probability - 0.0048
# Class 2: Probability - 0.0000
# Class 3: Probability - 0.9881
# Class 4: Probability - 0.0000
# Class 5: Probability - 0.0000
# Class 6: Probability - 0.0071
# Sample 419 - Probabilities for each class:
# Class 0: Probability - 0.0015
# Class 1: Probability - 0.9973
# Class 2: Probability - 0.0000
# Class 3: Probability - 0.0005
# Class 4: Probability - 0.0004
# Class 5: Probability - 0.0002
# Class 6: Probability - 0.0001
# Sample 420 - Probabilities for each class:
# Class 0: Probability - 0.0472
# Class 1: Probability - 0.0050
# Class 2: Probability - 0.0021
# Class 3: Probability - 0.0001
# Class 4: Probability - 0.0091
# Class 5: Probability - 0.9342
# Class 6: Probability - 0.0023
# Sample 421 - Probabilities for each class:
# Class 0: Probability - 0.0004
# Class 1: Probability - 0.0002
# Class 2: Probability - 0.9735
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.0003
# Class 5: Probability - 0.0077
# Class 6: Probability - 0.0179
# Sample 422 - Probabilities for each class:
# Class 0: Probability - 0.0030
# Class 1: Probability - 0.0234
# Class 2: Probability - 0.0012
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.0127
# Class 5: Probability - 0.9553
# Class 6: Probability - 0.0044
# Sample 423 - Probabilities for each class:
# Class 0: Probability - 0.0001
# Class 1: Probability - 0.9950
# Class 2: Probability - 0.0004
# Class 3: Probability - 0.0031
# Class 4: Probability - 0.0003
# Class 5: Probability - 0.0006
# Class 6: Probability - 0.0004
# Sample 424 - Probabilities for each class:
# Class 0: Probability - 0.0001
# Class 1: Probability - 0.0060
# Class 2: Probability - 0.0003
# Class 3: Probability - 0.0017
# Class 4: Probability - 0.0002
# Class 5: Probability - 0.0076
# Class 6: Probability - 0.9841
# Sample 425 - Probabilities for each class:
# Class 0: Probability - 0.9757
# Class 1: Probability - 0.0148
# Class 2: Probability - 0.0001
# Class 3: Probability - 0.0002
# Class 4: Probability - 0.0011
# Class 5: Probability - 0.0049
# Class 6: Probability - 0.0033
# Sample 426 - Probabilities for each class:
# Class 0: Probability - 0.0001
# Class 1: Probability - 0.0060
# Class 2: Probability - 0.0003
# Class 3: Probability - 0.0017
# Class 4: Probability - 0.0002
# Class 5: Probability - 0.0076
# Class 6: Probability - 0.9841
# Sample 427 - Probabilities for each class:
# Class 0: Probability - 0.0258
# Class 1: Probability - 0.0008
# Class 2: Probability - 0.0461
# Class 3: Probability - 0.0001
# Class 4: Probability - 0.9024
# Class 5: Probability - 0.0233
# Class 6: Probability - 0.0015
# Sample 428 - Probabilities for each class:
# Class 0: Probability - 0.0012
# Class 1: Probability - 0.0005
# Class 2: Probability - 0.0017
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.9743
# Class 5: Probability - 0.0223
# Class 6: Probability - 0.0000
# Sample 429 - Probabilities for each class:
# Class 0: Probability - 0.9672
# Class 1: Probability - 0.0252
# Class 2: Probability - 0.0007
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.0006
# Class 5: Probability - 0.0063
# Class 6: Probability - 0.0000
# Sample 430 - Probabilities for each class:
# Class 0: Probability - 0.0066
# Class 1: Probability - 0.0008
# Class 2: Probability - 0.0001
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.0001
# Class 5: Probability - 0.9924
# Class 6: Probability - 0.0000
# Sample 431 - Probabilities for each class:
# Class 0: Probability - 0.0013
# Class 1: Probability - 0.0001
# Class 2: Probability - 0.0015
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.9691
# Class 5: Probability - 0.0281
# Class 6: Probability - 0.0000
# Sample 432 - Probabilities for each class:
# Class 0: Probability - 0.0000
# Class 1: Probability - 0.0086
# Class 2: Probability - 0.0000
# Class 3: Probability - 0.9883
# Class 4: Probability - 0.0000
# Class 5: Probability - 0.0000
# Class 6: Probability - 0.0031
# Sample 433 - Probabilities for each class:
# Class 0: Probability - 0.0077
# Class 1: Probability - 0.0010
# Class 2: Probability - 0.2390
# Class 3: Probability - 0.0005
# Class 4: Probability - 0.7499
# Class 5: Probability - 0.0015
# Class 6: Probability - 0.0004
# Sample 434 - Probabilities for each class:
# Class 0: Probability - 0.0184
# Class 1: Probability - 0.9761
# Class 2: Probability - 0.0002
# Class 3: Probability - 0.0001
# Class 4: Probability - 0.0000
# Class 5: Probability - 0.0026
# Class 6: Probability - 0.0026
# Sample 435 - Probabilities for each class:
# Class 0: Probability - 0.0002
# Class 1: Probability - 0.0042
# Class 2: Probability - 0.0009
# Class 3: Probability - 0.0001
# Class 4: Probability - 0.0002
# Class 5: Probability - 0.0389
# Class 6: Probability - 0.9555
# Sample 436 - Probabilities for each class:
# Class 0: Probability - 0.0000
# Class 1: Probability - 0.0053
# Class 2: Probability - 0.0000
# Class 3: Probability - 0.9946
# Class 4: Probability - 0.0000
# Class 5: Probability - 0.0000
# Class 6: Probability - 0.0001
# Sample 437 - Probabilities for each class:
# Class 0: Probability - 0.0000
# Class 1: Probability - 0.0062
# Class 2: Probability - 0.0003
# Class 3: Probability - 0.9923
# Class 4: Probability - 0.0000
# Class 5: Probability - 0.0000
# Class 6: Probability - 0.0012
# Sample 438 - Probabilities for each class:
# Class 0: Probability - 0.0148
# Class 1: Probability - 0.8920
# Class 2: Probability - 0.0007
# Class 3: Probability - 0.0058
# Class 4: Probability - 0.0097
# Class 5: Probability - 0.0748
# Class 6: Probability - 0.0021
# Sample 439 - Probabilities for each class:
# Class 0: Probability - 0.0004
# Class 1: Probability - 0.0035
# Class 2: Probability - 0.0000
# Class 3: Probability - 0.9642
# Class 4: Probability - 0.0315
# Class 5: Probability - 0.0004
# Class 6: Probability - 0.0000
# Sample 440 - Probabilities for each class:
# Class 0: Probability - 0.0001
# Class 1: Probability - 0.0011
# Class 2: Probability - 0.0003
# Class 3: Probability - 0.0001
# Class 4: Probability - 0.0001
# Class 5: Probability - 0.0018
# Class 6: Probability - 0.9965
# Sample 441 - Probabilities for each class:
# Class 0: Probability - 0.0000
# Class 1: Probability - 0.0015
# Class 2: Probability - 0.0000
# Class 3: Probability - 0.0003
# Class 4: Probability - 0.0001
# Class 5: Probability - 0.0010
# Class 6: Probability - 0.9971
# Sample 442 - Probabilities for each class:
# Class 0: Probability - 0.0022
# Class 1: Probability - 0.0006
# Class 2: Probability - 0.0011
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.0021
# Class 5: Probability - 0.0133
# Class 6: Probability - 0.9807
# Sample 443 - Probabilities for each class:
# Class 0: Probability - 0.0002
# Class 1: Probability - 0.9984
# Class 2: Probability - 0.0000
# Class 3: Probability - 0.0014
# Class 4: Probability - 0.0000
# Class 5: Probability - 0.0000
# Class 6: Probability - 0.0000
# Sample 444 - Probabilities for each class:
# Class 0: Probability - 0.0000
# Class 1: Probability - 0.0000
# Class 2: Probability - 0.9928
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.0057
# Class 5: Probability - 0.0015
# Class 6: Probability - 0.0001
# Sample 445 - Probabilities for each class:
# Class 0: Probability - 0.0000
# Class 1: Probability - 0.0041
# Class 2: Probability - 0.0000
# Class 3: Probability - 0.9958
# Class 4: Probability - 0.0000
# Class 5: Probability - 0.0000
# Class 6: Probability - 0.0001
# Sample 446 - Probabilities for each class:
# Class 0: Probability - 0.0005
# Class 1: Probability - 0.0902
# Class 2: Probability - 0.0003
# Class 3: Probability - 0.0001
# Class 4: Probability - 0.0000
# Class 5: Probability - 0.0177
# Class 6: Probability - 0.8911
# Sample 447 - Probabilities for each class:
# Class 0: Probability - 0.0076
# Class 1: Probability - 0.0008
# Class 2: Probability - 0.0001
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.0003
# Class 5: Probability - 0.9913
# Class 6: Probability - 0.0000
# Sample 448 - Probabilities for each class:
# Class 0: Probability - 0.0303
# Class 1: Probability - 0.0125
# Class 2: Probability - 0.0001
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.0028
# Class 5: Probability - 0.9541
# Class 6: Probability - 0.0002
# Sample 449 - Probabilities for each class:
# Class 0: Probability - 0.9870
# Class 1: Probability - 0.0102
# Class 2: Probability - 0.0000
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.0005
# Class 5: Probability - 0.0023
# Class 6: Probability - 0.0000
# Sample 450 - Probabilities for each class:
# Class 0: Probability - 0.0017
# Class 1: Probability - 0.0011
# Class 2: Probability - 0.0437
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.9212
# Class 5: Probability - 0.0323
# Class 6: Probability - 0.0000
# Sample 451 - Probabilities for each class:
# Class 0: Probability - 0.0000
# Class 1: Probability - 0.0036
# Class 2: Probability - 0.0000
# Class 3: Probability - 0.9954
# Class 4: Probability - 0.0000
# Class 5: Probability - 0.0000
# Class 6: Probability - 0.0010
# Sample 452 - Probabilities for each class:
# Class 0: Probability - 0.0064
# Class 1: Probability - 0.0001
# Class 2: Probability - 0.9381
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.0012
# Class 5: Probability - 0.0235
# Class 6: Probability - 0.0308
# Sample 453 - Probabilities for each class:
# Class 0: Probability - 0.9907
# Class 1: Probability - 0.0067
# Class 2: Probability - 0.0000
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.0002
# Class 5: Probability - 0.0024
# Class 6: Probability - 0.0000
# Sample 454 - Probabilities for each class:
# Class 0: Probability - 0.0066
# Class 1: Probability - 0.0008
# Class 2: Probability - 0.0001
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.0001
# Class 5: Probability - 0.9924
# Class 6: Probability - 0.0000
# Sample 455 - Probabilities for each class:
# Class 0: Probability - 0.0382
# Class 1: Probability - 0.7112
# Class 2: Probability - 0.0364
# Class 3: Probability - 0.0114
# Class 4: Probability - 0.0037
# Class 5: Probability - 0.1083
# Class 6: Probability - 0.0908
# Sample 456 - Probabilities for each class:
# Class 0: Probability - 0.0197
# Class 1: Probability - 0.0230
# Class 2: Probability - 0.9493
# Class 3: Probability - 0.0001
# Class 4: Probability - 0.0062
# Class 5: Probability - 0.0016
# Class 6: Probability - 0.0000
# Sample 457 - Probabilities for each class:
# Class 0: Probability - 0.0001
# Class 1: Probability - 0.0168
# Class 2: Probability - 0.0000
# Class 3: Probability - 0.0002
# Class 4: Probability - 0.0000
# Class 5: Probability - 0.0084
# Class 6: Probability - 0.9746
# Sample 458 - Probabilities for each class:
# Class 0: Probability - 0.0274
# Class 1: Probability - 0.0562
# Class 2: Probability - 0.0037
# Class 3: Probability - 0.0023
# Class 4: Probability - 0.0054
# Class 5: Probability - 0.9021
# Class 6: Probability - 0.0028
# Sample 459 - Probabilities for each class:
# Class 0: Probability - 0.0000
# Class 1: Probability - 0.0174
# Class 2: Probability - 0.0000
# Class 3: Probability - 0.9811
# Class 4: Probability - 0.0000
# Class 5: Probability - 0.0001
# Class 6: Probability - 0.0014
# Sample 460 - Probabilities for each class:
# Class 0: Probability - 0.0010
# Class 1: Probability - 0.0000
# Class 2: Probability - 0.0001
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.9945
# Class 5: Probability - 0.0043
# Class 6: Probability - 0.0002
# Sample 461 - Probabilities for each class:
# Class 0: Probability - 0.0032
# Class 1: Probability - 0.0019
# Class 2: Probability - 0.0008
# Class 3: Probability - 0.0019
# Class 4: Probability - 0.9806
# Class 5: Probability - 0.0113
# Class 6: Probability - 0.0004
# Sample 462 - Probabilities for each class:
# Class 0: Probability - 0.0012
# Class 1: Probability - 0.0015
# Class 2: Probability - 0.9959
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.0003
# Class 5: Probability - 0.0012
# Class 6: Probability - 0.0000
# Sample 463 - Probabilities for each class:
# Class 0: Probability - 0.0012
# Class 1: Probability - 0.0009
# Class 2: Probability - 0.0001
# Class 3: Probability - 0.0000
# Class 4: Probability - 0.0000
# Class 5: Probability - 0.9977
# Class 6: Probability - 0.0000
# Sample 464 - Probabilities for each class:
# Class 0: Probability - 0.0070
# Class 1: Probability - 0.0167
# Class 2: Probability - 0.0090
# Class 3: Probability - 0.0001
# Class 4: Probability - 0.0018
# Class 5: Probability - 0.9586
# Class 6: Probability - 0.0067
# Sample 465 - Probabilities for each class:
# Class 0: Probability - 0.0002
# Class 1: Probability - 0.0169
# Class 2: Probability - 0.9765
# Class 3: Probability - 0.0002
# Class 4: Probability - 0.0038
# Class 5: Probability - 0.0023
# Class 6: Probability - 0.0001
# Average scores across all folds:
# Accuracy: 98.66952776908875 (+- 2.244104457638534)
# Loss: 0.11956750750541686 (+- 0.1272528834202504)
# Epoch 1/10
# 73/73 [==============================] - 9s 98ms/step - loss: 6.0380 - accuracy: 0.3452
# Epoch 2/10
# 73/73 [==============================] - 7s 98ms/step - loss: 0.7528 - accuracy: 0.7699
# Epoch 3/10
# 73/73 [==============================] - 7s 96ms/step - loss: 0.4216 - accuracy: 0.9073
# Epoch 4/10
# 73/73 [==============================] - 8s 104ms/step - loss: 0.2985 - accuracy: 0.9339
# Epoch 5/10
# 73/73 [==============================] - 7s 103ms/step - loss: 0.1772 - accuracy: 0.9798
# Epoch 6/10
# 73/73 [==============================] - 7s 101ms/step - loss: 0.1292 - accuracy: 0.9884
# Epoch 7/10
# 73/73 [==============================] - 7s 99ms/step - loss: 0.0886 - accuracy: 0.9957
# Epoch 8/10
# 73/73 [==============================] - 7s 97ms/step - loss: 0.0674 - accuracy: 0.9991
# Epoch 9/10
# 73/73 [==============================] - 7s 97ms/step - loss: 0.0539 - accuracy: 0.9996
# Epoch 10/10
# 73/73 [==============================] - 7s 98ms/step - loss: 0.0419 - accuracy: 1.0000
# Test Accuracy: 26.25%
